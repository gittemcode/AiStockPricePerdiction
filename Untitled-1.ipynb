# %% [markdown]
# # Setup the import statements as well as create the sp500 variable to hold all of the S & P 500 values throughout history

# %% [markdown]
# ### Import statements for all of the external libraries that we are going to be using

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import yfinance as yf

# %% [markdown]
# ### Initalize the ticker class alowing us to download price history for a single symbol

# %%
# The GSPC symbol represents the S & P 500 index
sp500 = yf.Ticker("^GSPC")

# %% [markdown]
# ### Query the historical prices for the S & P 500

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-12-24 00:00:00-05:00  5984.629883  6040.100098  5981.439941  6040.040039
# 2024-12-26 00:00:00-05:00  6024.970215  6049.750000  6007.370117  6037.589844
# 2024-12-27 00:00:00-05:00  6006.169922  6006.169922  5932.950195  5970.839844
# 2024-12-30 00:00:00-05:00  5920.669922  5940.790039  5869.160156  5906.939941
# 2024-12-31 00:00:00-05:00  5919.740234  5929.740234  5868.859863  5881.629883
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2024-12-24 00:00:00-05:00  1757720000        0.0           0.0
# 2024-12-26 00:00:00-05:00  2904530000        0.0           0.0
# 2024-12-27 00:00:00-05:00  3159610000        0.0           0.0
# 2024-12-30 00:00:00-05:00  3433250000        0.0           0.0
# 2024-12-31 00:00:00-05:00  3128350000        0.0           0.0
#
# [24367 rows x 7 columns]

# %% [markdown]
# # Cleaning and visualizing the stock market

# %% [markdown]
# ### Create a visualization of all of the market values throughout time

# %%
sp500.plot.line(y="Close", use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Delete and clean up some of the non esential data like the dividends

# %%
del sp500['Dividends'] 
# can delete stock splits here but may want to in the future look at a specified stock   
sp500.index = pd.to_datetime(sp500.index).date # can change the index this way which represents the dates and time

# %% [markdown]
# # Set up the target for machine learning

# %% [markdown]
# ### Create a target for if the stock price will go up or down tomorrow by creating a new column in the dataset representing the prive on the previous day

# %%
sp500['Tomorrow'] = sp500['Close'].shift(-1) 
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2024-12-24  5984.629883  6040.100098  5981.439941  6040.040039  1757720000
# 2024-12-26  6024.970215  6049.750000  6007.370117  6037.589844  2904530000
# 2024-12-27  6006.169922  6006.169922  5932.950195  5970.839844  3159610000
# 2024-12-30  5920.669922  5940.790039  5869.160156  5906.939941  3433250000
# 2024-12-31  5919.740234  5929.740234  5868.859863  5881.629883  3128350000
#
#             Stock Splits     Tomorrow
# 1927-12-30           0.0    17.760000
# 1928-01-03           0.0    17.719999
# 1928-01-04           0.0    17.549999
# 1928-01-05           0.0    17.660000
# 1928-01-06           0.0    17.500000
# ...                  ...          ...
# 2024-12-24           0.0  6037.589844
# 2024-12-26           0.0  5970.839844
# 2024-12-27           0.0  5906.939941
# 2024-12-30           0.0  5881.629883
# 2024-12-31           0.0          NaN
#
# [24367 rows x 7 columns]

# %% [markdown]
# ### Create a new column for the target which is what we are going to try and perdict

# %%
sp500['Target'] = (sp500['Tomorrow'] > sp500['Close']).astype(int)
sp500
# Out:
#                    Open         High          Low        Close      Volume  \


# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Initalize the model and add parameters

# %%
# n_estimators is the amount of decision trees, the more the better  
# min_samples_split helps us protect against overfitting the higher we set it the less accurate the model will be but the less it will overfit, 
# random state is how random the imput parameters will be 

model = RandomForestClassifier(n_estimators=200, min_samples_split=100,random_state=1) 
print(type(sp500))
train = sp500.iloc[:-100] 
test = sp500.iloc[-100:]

predictors = ["Close", "Open", "High", "Low", "Volume"] 

model.fit(train[predictors], train["Target"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RandomForestClassifier(min_samples_split=100, n_estimators=200, random_state=1)

# %% [markdown]
# ### Checks for the model if the model is being trained accurately

# %%
from sklearn.metrics import precision_score 

preds = model.predict(test[predictors]) 
preds = pd.Series(preds, index=test.index) 
preds
# Out:
# 2024-08-09    1
# 2024-08-12    1
# 2024-08-13    1
# 2024-08-14    1
# 2024-08-15    1
#              ..
# 2024-12-24    0
# 2024-12-26    0
# 2024-12-27    0
# 2024-12-30    0
# 2024-12-31    0
# Length: 100, dtype: int64

# %% [markdown]
# ### Now we calculate the percision scroe here and then can adjust the model as needed

# %%
precision_score(test["Target"], preds)
# Out:
# 0.8095238095238095

# %% [markdown]
# ### Now we will plot the predictions to visualize it

# %%
combined = pd.concat([test['Target'], preds], axis=1) 
combined.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Building a backtesting system

# %% [markdown]
# ### Currently only able to test across the last 100 days but we want to know how our model will handle multiple situations

# %% [markdown]
# ### Function for fitting of the model using the training data and the target

# %%
def perdict(train, test, predictors, model): 
    model.fit(train[predictors], train['Target']) 
    preds = model.predict(test[predictors]) 
    preds = pd.Series(preds, index=test.index, name="Predictions") 
    combined = pd.concat([test['Target'], preds], axis=1)  
    return combined

# %% [markdown]
# ### A backtesting function taking in the data, the model, the predictors, the start value (the amount of data to take a model), and a step which is how long the model is trained for

# %%
def backtest(data, model, predictors, start=2500, step=250): 
    all_predictions = [] 
    for i in range(start, data.shape[0], step): 
        train = data.iloc[0:i].copy() # everything prior to the current year
        test = data.iloc[i:(i + step)].copy() # the current year  
        perdiction = perdict(train,test,predictors,model) 
        all_predictions.append(perdiction) 
    return pd.concat(all_predictions)

# %% [markdown]
# ### Now with thest functions we can backtest the S & P 500 data with the model and predictors we have created earlier. Once we see this we can see where our predictions were wrong

# %%
predictions = backtest(sp500, model, predictors)  
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0    3654
# 1    2663
# Name: count, dtype: int64

# %% [markdown]
# ### Now we find the percision score based on our model this tells us how many of the positive predictions made by a model are actually correct. This will tell us how many days we have predicted the prices rising

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.524971836274878

# %% [markdown]
# ### Across the training days we were only 52% accurate at predicting if the market price will rise or fall. Now we can use this as a benchmark and see the percentage days where the market actually went up. to do this we can look at the value counts of the target and divide it by the total number of rows

# %%
predictions['Target'].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.535856
# 0    0.464144
# Name: count, dtype: float64

# %% [markdown]
# # Adding additional predictors to the model to make it more accurate

# %% [markdown]
# ### Create a variety of rolling averages to help aid our model

# %%
horizons = [2,5,60,250,1000] 
new_predictors = [] 
for horizon in horizons: 
    rolling_averages = sp500.rolling(horizon).mean() 

    ratio_column = f"Close_Ratio_{horizon}" 
    sp500[ratio_column] = sp500['Close'] / rolling_averages['Close'] 

    trend_column = f"Trend_{horizon}" 
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()['Target'] 
    # On any given day it is going to look at the past few days and find the sum of the target  

    new_predictors += [ratio_column, trend_column]

# %% [markdown]
# ### Creates lots of NaN entired because pandas can not get enough days before to compute a rolling average

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2024-12-24  5984.629883  6040.100098  5981.439941  6040.040039  1757720000
# 2024-12-26  6024.970215  6049.750000  6007.370117  6037.589844  2904530000
# 2024-12-27  6006.169922  6006.169922  5932.950195  5970.839844  3159610000
# 2024-12-30  5920.669922  5940.790039  5869.160156  5906.939941  3433250000
# 2024-12-31  5919.740234  5929.740234  5868.859863  5881.629883  3128350000
#
#             Stock Splits     Tomorrow  Target  Close_Ratio_2  Trend_2  \
# 1990-01-02           0.0   358.760010       0            NaN      NaN
# 1990-01-03           0.0   355.670013       0       0.998706      NaN
# 1990-01-04           0.0   352.200012       0       0.995675      0.0
# 1990-01-05           0.0   353.790009       1       0.995098      0.0
# 1990-01-08           0.0   349.619995       0       1.002252      1.0
# ...                  ...          ...     ...            ...      ...
# 2024-12-24           0.0  6037.589844       0       1.005491      2.0
# 2024-12-26           0.0  5970.839844       0       0.999797      1.0
# 2024-12-27           0.0  5906.939941       0       0.994441      0.0
# 2024-12-30           0.0  5881.629883       0       0.994620      0.0
# 2024-12-31           0.0          NaN       0       0.997853      0.0
#
#             Close_Ratio_5  Trend_5  Close_Ratio_60  Trend_60  Close_Ratio_250  \
# 1990-01-02            NaN      NaN             NaN       NaN              NaN
# 1990-01-03            NaN      NaN             NaN       NaN              NaN
# 1990-01-04            NaN      NaN             NaN       NaN              NaN
# 1990-01-05            NaN      NaN             NaN       NaN              NaN
# 1990-01-08       0.993731      NaN             NaN       NaN              NaN
# ...                   ...      ...             ...       ...              ...
# 2024-12-24       1.017383      3.0        1.023002      35.0         1.115492
# 2024-12-26       1.011334      3.0        1.021639      35.0         1.114008
# 2024-12-27       0.996689      3.0        1.009600      34.0         1.100716
# 2024-12-30       0.986810      2.0        0.998213      34.0         1.088002
# 2024-12-31       0.985626      1.0        0.993570      33.0         1.082402
#
#             Trend_250  Close_Ratio_1000  Trend_1000
# 1990-01-02        NaN               NaN         NaN
# 1990-01-03        NaN               NaN         NaN
# 1990-01-04        NaN               NaN         NaN
# 1990-01-05        NaN               NaN         NaN
# 1990-01-08        NaN               NaN         NaN
# ...               ...               ...         ...
# 2024-12-24      144.0          1.337188       531.0
# 2024-12-26      143.0          1.335962       530.0
# 2024-12-27      143.0          1.320543       529.0
# 2024-12-30      143.0          1.305803       528.0
# 2024-12-31      143.0          1.299617       527.0
#
# [8817 rows x 18 columns]

# %% [markdown]
# ### Clearn up the data by dropping all the columns with NaN entires

# %%
sp500 = sp500.dropna() 
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
